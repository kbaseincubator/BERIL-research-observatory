# %% [markdown]
# # M. extorquens B Vitamin Biosynthesis and Lanthanide C1 Metabolism
#
# *Methylobacterium extorquens* AM1 ([NCBI Taxonomy 272630](https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=272630)) is the model organism for lanthanide-dependent methylotrophy. It carries two methanol dehydrogenases:
#
# - **XoxF**: lanthanide-dependent PQQ methanol dehydrogenase (uses La, Ce, or other rare earth elements)
# - **MxaF**: calcium-dependent PQQ methanol dehydrogenase (the classical enzyme)
#
# These represent fundamentally different C1 metabolic modes. This notebook asks:
#
# 1. Is *M. extorquens* auxotrophic for any B vitamins? Which biosynthesis pathways are complete vs incomplete?
# 2. What does that mean for optimal growth medium design?
# 3. Do xoxF-carrying *Methylobacterium* species show different B vitamin profiles than mxaF-only species?
#
# **Portability**: This notebook uses Spark SQL on BERDL JupyterHub. Queries can be adapted for the KBase MCP REST API for workstation use, though the multi-table joins perform best on Spark.

# %% [markdown]
# ## 1. Setup

# %%
from berdl_notebook_utils import get_spark_session
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

spark = get_spark_session("MextorquensBvitamin")

# %% [markdown]
# ## 2. Identify M. extorquens in the pangenome
#
# GTDB retains the name *Methylobacterium* for this lineage, while NCBI recently reclassified some strains as *Methylorubrum*. We search for both.

# %%
spark.sql("""
    SELECT s.GTDB_species, s.gtdb_species_clade_id,
           p.no_genomes, p.no_core, p.no_gene_clusters,
           p.no_aux_genome, p.no_singleton_gene_clusters
    FROM kbase_ke_pangenome.pangenome p
    JOIN kbase_ke_pangenome.gtdb_species_clade s
      ON p.gtdb_species_clade_id = s.gtdb_species_clade_id
    WHERE s.GTDB_species LIKE '%extorquens%'
       OR s.GTDB_species LIKE '%Methylorubrum%'
""").show(truncate=False)
# Out:
# +--------------------------------+----------------------------------------------------+----------+-------+----------------+-------------+--------------------------+
# |GTDB_species                    |gtdb_species_clade_id                               |no_genomes|no_core|no_gene_clusters|no_aux_genome|no_singleton_gene_clusters|
# +--------------------------------+----------------------------------------------------+----------+-------+----------------+-------------+--------------------------+
# |s__Methylobacterium_extorquens  |s__Methylobacterium_extorquens--RS_GCF_900234795.1  |22        |3920   |18929           |15009        |9286.0                    |
# |s__Methylobacterium_extorquens_A|s__Methylobacterium_extorquens_A--RS_GCF_024169925.1|4         |4272   |5486            |1214         |646.0                     |
# +--------------------------------+----------------------------------------------------+----------+-------+----------------+-------------+--------------------------+

# %% [markdown]
# ## 3. B vitamin biosynthesis gene survey
#
# We search eggNOG annotations for key genes in six B vitamin biosynthesis pathways. For each pathway, we define the expected biosynthesis genes and their KEGG orthologs.

# %%
B_VITAMIN_PATHWAYS = {
    'B1_thiamine': {
        'kegg_pathway': 'ko00730',
        'key_genes': ['thiC', 'thiD', 'thiE', 'thiG', 'thiL', 'thiM', 'thiO', 'thiS'],
        'key_kos': ['K03147', 'K00788', 'K00946', 'K03149', 'K00948', 'K00878']
    },
    'B2_riboflavin': {
        'kegg_pathway': 'ko00740',
        'key_genes': ['ribA', 'ribB', 'ribC', 'ribD', 'ribE', 'ribH'],
        'key_kos': ['K02858', 'K14652', 'K00793', 'K11752', 'K00794', 'K02857']
    },
    'B6_pyridoxine': {
        'kegg_pathway': 'ko00750',
        'key_genes': ['pdxA', 'pdxB', 'pdxJ', 'pdxH', 'pdxK'],
        'key_kos': ['K00097', 'K06215', 'K03474', 'K00275', 'K00868']
    },
    'B7_biotin': {
        'kegg_pathway': 'ko00780',
        'key_genes': ['bioA', 'bioB', 'bioC', 'bioD', 'bioF', 'bioH'],
        'key_kos': ['K00833', 'K01012', 'K02169', 'K01935', 'K00652', 'K02170']
    },
    'B9_folate': {
        'kegg_pathway': 'ko00790',
        'key_genes': ['folA', 'folB', 'folC', 'folE', 'folK', 'folP', 'pabA', 'pabB'],
        'key_kos': ['K00287', 'K01633', 'K11754', 'K01495', 'K00950', 'K00796']
    },
    'B12_cobalamin': {
        'kegg_pathway': 'ko00860',
        'key_genes': ['cobA', 'cobB', 'cobC', 'cobD', 'cobE', 'cobG', 'cobH',
                       'cobI', 'cobJ', 'cobK', 'cobL', 'cobM', 'cobN', 'cobO',
                       'cobP', 'cobQ', 'cobR', 'cobS', 'cobT', 'cobU', 'cobW',
                       'bluB', 'btuR'],
        'key_kos': ['K00798', 'K02224', 'K02225', 'K02227', 'K02229', 'K02230',
                     'K02231', 'K02232', 'K02233', 'K13786', 'K02236', 'K19221']
    }
}

# %% [markdown]
# ## 4. Query B vitamin genes for M. extorquens
#
# Search by both gene name (`Preferred_name`) and KEGG pathway membership.

# %%
# Collect all gene names across pathways
all_genes = []
for pathway, info in B_VITAMIN_PATHWAYS.items():
    all_genes.extend(info['key_genes'])
gene_list = "','".join(all_genes)

bvit_annotations = spark.sql(f"""
    SELECT
        e.query_name as gene_cluster_id,
        e.Preferred_name,
        e.EC,
        e.KEGG_ko,
        e.KEGG_Pathway,
        e.Description,
        e.COG_category,
        gc.is_core,
        gc.is_auxiliary,
        gc.is_singleton
    FROM kbase_ke_pangenome.eggnog_mapper_annotations e
    JOIN kbase_ke_pangenome.gene_cluster gc
        ON e.query_name = gc.gene_cluster_id
    JOIN kbase_ke_pangenome.gtdb_species_clade sc
        ON gc.gtdb_species_clade_id = sc.gtdb_species_clade_id
    WHERE sc.GTDB_species LIKE '%extorquens%'
      AND (e.Preferred_name IN ('{gene_list}')
        OR e.KEGG_Pathway LIKE '%00730%'
        OR e.KEGG_Pathway LIKE '%00740%'
        OR e.KEGG_Pathway LIKE '%00750%'
        OR e.KEGG_Pathway LIKE '%00780%'
        OR e.KEGG_Pathway LIKE '%00790%'
        OR e.KEGG_Pathway LIKE '%00860%')
    ORDER BY e.KEGG_Pathway, e.Preferred_name
""")

bvit_pd = bvit_annotations.toPandas()
print(f"Total B vitamin-related gene clusters found: {len(bvit_pd)}")
bvit_pd
# Out:
# Total B vitamin-related gene clusters found: 360
#                gene_cluster_id Preferred_name                 EC    KEGG_ko  \
# 0           LMNQ01000006.1_117           bioC                  -          -
# 1    NZ_JALJXD010000001.1_4296           bioC                  -          -
# 2    NZ_JALJXE010000001.1_1326           cobB                  -  ko:K12410
# 3       JALKFF010000001.1_4207           cobB                  -  ko:K12410
# 4    NZ_JALJXF010000001.1_4227           cobW                  -  ko:K02234
# ..                         ...            ...                ...        ...
# 355           NC_011757.1_2907           bchZ  1.3.7.14,1.3.7.15  ko:K11335
# 356  NZ_JALJXF010000001.1_4137            bfr           1.16.3.1  ko:K03594
# 357         LMMQ01000034.1_171            bfr           1.16.3.1  ko:K03594
# 358   NZ_JALJXF010000001.1_388           thiS                  -  ko:K03154
# 359         LMNP01000002.1_149           thiS                  -  ko:K03154
#
#                           KEGG_Pathway  \
# 0                                    -
# 1                                    -
# 2                                    -
# 3                                    -
# 4                                    -
# ..                                 ...
# 355  ko00860,ko01110,map00860,map01110
# 356                   ko00860,map00860
# 357                   ko00860,map00860
# 358                   ko04122,map04122
# 359                   ko04122,map04122
#
#                                            Description COG_category  is_core  \
# 0                       PFAM Methyltransferase type 11            Q     True
# 1                       PFAM Methyltransferase type 11            Q     True
# 2    NAD-dependent lysine deacetylase and desucciny...            K     True
# 3    NAD-dependent lysine deacetylase and desucciny...            K     True
# 4                  cobalamin biosynthesis protein CobW            S     True
# ..                                                 ...          ...      ...
# 355         TIGRFAM chlorophyllide reductase subunit Z            C     True
# 356  Iron-storage protein, whose ferroxidase center...            P     True
# 357  Iron-storage protein, whose ferroxidase center...            P     True
# 358         TIGRFAM thiamine biosynthesis protein ThiS            H     True
# 359         TIGRFAM thiamine biosynthesis protein ThiS            H     True
#
#      is_auxiliary  is_singleton
# 0           False         False
# 1           False         False
# 2           False         False
# 3           False         False
# 4           False         False
# ..            ...           ...
# 355         False         False
# 356         False         False
# 357         False         False
# 358         False         False
# 359         False         False
#
# [360 rows x 10 columns]

# %% [markdown]
# ## 5. Pathway completeness assessment
#
# Map each found gene to its B vitamin pathway and identify which pathways are complete vs incomplete.

# %%
def classify_bvit_pathway(row):
    """Classify a gene cluster annotation into a B vitamin pathway.
    Matches by gene name (key_genes) and KEGG KO (key_kos).
    Does NOT match by KEGG pathway number, which pulls in
    contamination from related pathways (e.g., bch* into B12,
    moa*/que* into B9).
    """
    name = row.get('Preferred_name', '')
    kegg_ko = str(row.get('KEGG_ko', ''))

    for pathway, info in B_VITAMIN_PATHWAYS.items():
        if name in info['key_genes']:
            return pathway
        for ko in info['key_kos']:
            if ko in kegg_ko:
                return pathway
    return 'other'

bvit_pd['pathway'] = bvit_pd.apply(classify_bvit_pathway, axis=1)
bvit_classified = bvit_pd[bvit_pd['pathway'] != 'other'].copy()

print("=== B Vitamin Pathway Completeness in M. extorquens ===")
print()
for pathway, info in B_VITAMIN_PATHWAYS.items():
    expected_genes = set(info['key_genes'])
    found_genes = set(bvit_classified[bvit_classified['pathway'] == pathway]['Preferred_name'].unique())
    found_in_expected = found_genes & expected_genes
    missing = expected_genes - found_genes

    completeness = len(found_in_expected) / len(expected_genes) * 100 if expected_genes else 0

    print(f"{pathway}:")
    print(f"  Found: {sorted(found_in_expected)} ({len(found_in_expected)}/{len(expected_genes)})")
    print(f"  Missing: {sorted(missing)}")
    print(f"  Completeness: {completeness:.0f}%")

    pathway_clusters = bvit_classified[bvit_classified['pathway'] == pathway]
    n_core = pathway_clusters['is_core'].sum()
    n_aux = pathway_clusters['is_auxiliary'].sum()
    n_sing = pathway_clusters['is_singleton'].sum()
    print(f"  Core/Auxiliary/Singleton: {n_core}/{n_aux}/{n_sing}")
    print()
# Out:
# === B Vitamin Pathway Completeness in M. extorquens ===
#
# B1_thiamine:
#   Found: ['thiC', 'thiD', 'thiE', 'thiG', 'thiL', 'thiS'] (6/8)
#   Missing: ['thiM', 'thiO']
#   Completeness: 75%
#   Core/Auxiliary/Singleton: 18/3/3
#
# B2_riboflavin:
#   Found: ['ribB', 'ribD', 'ribE', 'ribH'] (4/6)
#   Missing: ['ribA', 'ribC']
#   Completeness: 67%
#   Core/Auxiliary/Singleton: 8/0/0
#
# B6_pyridoxine:
#   Found: ['pdxA', 'pdxB', 'pdxH', 'pdxJ'] (4/5)
#   Missing: ['pdxK']
#   Completeness: 80%
#   Core/Auxiliary/Singleton: 9/1/0
#
# B7_biotin:
#   Found: ['bioA', 'bioB', 'bioC', 'bioD', 'bioF', 'bioH'] (6/6)
#   Missing: []
#   Completeness: 100%
#   Core/Auxiliary/Singleton: 11/6/2
#
# B9_folate:
#   Found: ['folA', 'folB', 'folC', 'folE', 'folK', 'folP', 'pabA', 'pabB'] (8/8)
#   Missing: []
#   Completeness: 100%
#   Core/Auxiliary/Singleton: 18/1/1
#
# B12_cobalamin:
#   Found: ['bluB', 'cobA', 'cobB', 'cobC', 'cobD', 'cobG', 'cobH', 'cobI', 'cobJ', 'cobK', 'cobL', 'cobM', 'cobN', 'cobO', 'cobP', 'cobQ', 'cobS', 'cobT', 'cobW'] (19/23)
#   Missing: ['btuR', 'cobE', 'cobR', 'cobU']
#   Completeness: 83%
#   Core/Auxiliary/Singleton: 48/19/19

# %% [markdown]
# ## 6. Growth medium implications
#
# Missing biosynthesis genes predict auxotrophies — the organism cannot synthesize that vitamin and must obtain it from the medium. Standard *M. extorquens* AM1 media use methanol as carbon source with mineral salts. Some formulations add trace vitamins.
#
# **Caveat**: Missing annotations may reflect gaps in eggNOG sensitivity rather than true gene absence. Predictions should be validated experimentally.

# %%
MEDIUM_COMPONENTS = {
    'B1_thiamine': 'thiamine HCl',
    'B2_riboflavin': 'riboflavin',
    'B6_pyridoxine': 'pyridoxine HCl',
    'B7_biotin': 'biotin',
    'B9_folate': 'folic acid',
    'B12_cobalamin': 'cyanocobalamin or hydroxocobalamin'
}

print("=== Growth Medium Implications ===")
print()

predicted_supplements = []
for pathway, info in B_VITAMIN_PATHWAYS.items():
    expected_genes = set(info['key_genes'])
    found_genes = set(bvit_classified[bvit_classified['pathway'] == pathway]['Preferred_name'].unique())
    missing = expected_genes - found_genes
    completeness = len(found_genes & expected_genes) / len(expected_genes) * 100

    if completeness < 80:
        supplement = MEDIUM_COMPONENTS.get(pathway, 'unknown')
        predicted_supplements.append((pathway, supplement, f"{completeness:.0f}%"))
        print(f"PREDICTED AUXOTROPHY: {pathway}")
        print(f"  Pathway completeness: {completeness:.0f}%")
        print(f"  Recommended supplement: {supplement}")
        print(f"  Missing genes: {sorted(missing)}")
        print()

if not predicted_supplements:
    print("No clear auxotrophies predicted (all pathways >80% complete)")
    print("Note: this may undercount due to annotation sensitivity")

print()
print("Note: Standard M. extorquens AM1 medium typically includes")
print("methanol as carbon source with mineral salts. Some formulations")
print("add trace vitamins. These predictions should be validated by")
print("growth experiments with/without individual vitamin supplements.")
# Out:
# === Growth Medium Implications ===
#
# PREDICTED AUXOTROPHY: B1_thiamine
#   Pathway completeness: 75%
#   Recommended supplement: thiamine HCl
#   Missing genes: ['thiM', 'thiO']
#
# PREDICTED AUXOTROPHY: B2_riboflavin
#   Pathway completeness: 67%
#   Recommended supplement: riboflavin
#   Missing genes: ['ribA', 'ribC']
#
#
# Note: Standard M. extorquens AM1 medium typically includes
# methanol as carbon source with mineral salts. Some formulations
# add trace vitamins. These predictions should be validated by
# growth experiments with/without individual vitamin supplements.

# %% [markdown]
# ## 7. xoxF vs mxaF annotation audit
#
# A prior analysis of 150 methylotrophic species revealed that eggNOG sometimes annotates **xoxF** (lanthanide-dependent MDH) as `mxaF` with EC 1.1.2.8 / K00114. The true mxaF should have EC 1.1.2.7 / K14028. We audit all PQQ dehydrogenase annotations for *M. extorquens* to distinguish them.

# %%
mdh_all = spark.sql("""
    SELECT
        e.query_name as gene_cluster_id,
        e.Preferred_name,
        e.EC,
        e.KEGG_ko,
        e.Description,
        e.PFAMs,
        gc.is_core,
        gc.is_auxiliary,
        gc.is_singleton,
        sc.GTDB_species
    FROM kbase_ke_pangenome.eggnog_mapper_annotations e
    JOIN kbase_ke_pangenome.gene_cluster gc
        ON e.query_name = gc.gene_cluster_id
    JOIN kbase_ke_pangenome.gtdb_species_clade sc
        ON gc.gtdb_species_clade_id = sc.gtdb_species_clade_id
    WHERE sc.GTDB_species LIKE '%extorquens%'
      AND (e.Preferred_name IN ('xoxF', 'mxaF', 'mxaI', 'exaA')
        OR e.KEGG_ko LIKE '%K14028%'
        OR e.KEGG_ko LIKE '%K14029%'
        OR e.KEGG_ko LIKE '%K00114%'
        OR e.PFAMs LIKE '%PQQ%')
    ORDER BY sc.GTDB_species, e.Preferred_name, e.EC
""")

mdh_pd = mdh_all.toPandas()
print(f"Total PQQ MDH-related gene clusters in M. extorquens: {len(mdh_pd)}")
print()
print("=== MDH Classification ===")
print("Note: eggNOG sometimes annotates xoxF as 'mxaF' with EC 1.1.2.8 / K00114")
print("True mxaF should have EC 1.1.2.7 / K14028")
print()

for _, row in mdh_pd.iterrows():
    name = str(row['Preferred_name'])
    ec = str(row['EC'])
    kegg = str(row['KEGG_ko'])

    if name == 'xoxF':
        likely = 'xoxF (lanthanide-dependent)'
    elif name == 'mxaF' and 'K14028' in kegg:
        likely = 'mxaF (calcium-dependent, canonical)'
    elif name == 'mxaF' and ('K00114' in kegg or '1.1.2.8' in ec):
        likely = 'POSSIBLE xoxF (misannotated as mxaF, EC 1.1.2.8/K00114)'
    elif name == 'mxaI':
        likely = 'mxaI (small subunit)'
    elif name == 'exaA':
        likely = 'exaA (ethanol dehydrogenase, PQQ family)'
    else:
        likely = f'other PQQ enzyme ({name})'

    print(f"  {row['gene_cluster_id']}: {name} | EC={ec} | KEGG={kegg} | {likely}")
    print(f"    Core={row['is_core']} Aux={row['is_auxiliary']} Singleton={row['is_singleton']}")
    print(f"    PFAMs: {row['PFAMs']}")
    print()
# Out:
# Total PQQ MDH-related gene clusters in M. extorquens: 16
#
# === MDH Classification ===
# Note: eggNOG sometimes annotates xoxF as 'mxaF' with EC 1.1.2.8 / K00114
# True mxaF should have EC 1.1.2.7 / K14028
#
#   NC_011757.1_4921: - | EC=- | KEGG=- | other PQQ enzyme (-)
#     Core=True Aux=False Singleton=False
#     PFAMs: PQQ,PQQ_2,PQQ_3
#
#   NZ_CP019322.1_3007: - | EC=1.1.2.8 | KEGG=ko:K00114 | other PQQ enzyme (-)
#     Core=False Aux=True Singleton=True
#     PFAMs: PQQ,PQQ_2
#
#   NC_010172.1_100: - | EC=1.1.2.8 | KEGG=ko:K00114 | other PQQ enzyme (-)
#     Core=False Aux=True Singleton=False
#     PFAMs: PQQ,PQQ_2
#
#   NZ_JAKOAU010000012.1_124: - | EC=1.1.5.2 | KEGG=ko:K00117 | other PQQ enzyme (-)
#     Core=False Aux=True Singleton=True
#     PFAMs: PQQ,PQQ_2
#
#   NC_012808.1_1077: exaA | EC=1.1.2.8 | KEGG=ko:K00114 | exaA (ethanol dehydrogenase, PQQ family)
#     Core=True Aux=False Singleton=False
#     PFAMs: PQQ,PQQ_2
#
#   NC_011757.1_1105: gcd1 | EC=1.1.5.2 | KEGG=ko:K00117 | other PQQ enzyme (gcd1)
#     Core=False Aux=True Singleton=False
#     PFAMs: PQQ,PQQ_2
#
#   LMMQ01000023.1_241: mxaF | EC=1.1.2.7 | KEGG=ko:K14028 | mxaF (calcium-dependent, canonical)
#     Core=True Aux=False Singleton=False
#     PFAMs: PQQ
#
#   NZ_CP019322.1_4809: mxaF | EC=1.1.2.8 | KEGG=ko:K00114 | POSSIBLE xoxF (misannotated as mxaF, EC 1.1.2.8/K00114)
#     Core=True Aux=False Singleton=False
#     PFAMs: PQQ,PQQ_2
#
#   JALKFF010000001.1_3029: mxaF | EC=1.1.2.8 | KEGG=ko:K00114 | POSSIBLE xoxF (misannotated as mxaF, EC 1.1.2.8/K00114)
#     Core=False Aux=True Singleton=True
#     PFAMs: PQQ,PQQ_2
#
#   NC_012808.1_2613: mxaF | EC=1.1.2.8 | KEGG=ko:K00114 | POSSIBLE xoxF (misannotated as mxaF, EC 1.1.2.8/K00114)
#     Core=False Aux=True Singleton=False
#     PFAMs: PQQ,PQQ_2
#
#   JACJIN010000005.1_301: mxaI | EC=1.1.2.7 | KEGG=ko:K14029 | mxaI (small subunit)
#     Core=True Aux=False Singleton=False
#     PFAMs: MDH
#
#   NZ_JALJXF010000001.1_1353: - | EC=- | KEGG=- | other PQQ enzyme (-)
#     Core=True Aux=False Singleton=False
#     PFAMs: PQQ
#
#   NZ_JALJXE010000001.1_3666: - | EC=- | KEGG=- | other PQQ enzyme (-)
#     Core=True Aux=False Singleton=False
#     PFAMs: PQQ,PQQ_2,PQQ_3
#
#   JAKSYB010000075.1_116: mxaF | EC=1.1.2.7 | KEGG=ko:K14028 | mxaF (calcium-dependent, canonical)
#     Core=True Aux=False Singleton=False
#     PFAMs: PQQ
#
#   NZ_JALJXF010000001.1_3876: mxaF | EC=1.1.2.8 | KEGG=ko:K00114 | POSSIBLE xoxF (misannotated as mxaF, EC 1.1.2.8/K00114)
#     Core=True Aux=False Singleton=False
#     PFAMs: PQQ,PQQ_2
#
#   NZ_JALJXE010000001.1_3186: mxaI | EC=1.1.2.7 | KEGG=ko:K14029 | mxaI (small subunit)
#     Core=True Aux=False Singleton=False
#     PFAMs: MDH

# %% [markdown]
# ## 8. Cross-species: xoxF/mxaF and B vitamin correlation
#
# Do xoxF-carrying *Methylobacterium* species have different B vitamin biosynthesis profiles than mxaF-only species? If so, this would connect lanthanide biology to vitamin metabolism.

# %%
# Step 1: MDH profile per Methylobacterium/Methylorubrum species
# Uses EC/KEGG for classification (not Preferred_name alone),
# because cell b7 showed eggNOG misannotates xoxF as "mxaF" with EC 1.1.2.8/K00114.
mdh_all = spark.sql("""
    SELECT
        sc.GTDB_species,
        sc.gtdb_species_clade_id,
        e.query_name as gene_cluster_id,
        e.Preferred_name,
        e.EC,
        e.KEGG_ko
    FROM kbase_ke_pangenome.eggnog_mapper_annotations e
    JOIN kbase_ke_pangenome.gene_cluster gc
        ON e.query_name = gc.gene_cluster_id
    JOIN kbase_ke_pangenome.gtdb_species_clade sc
        ON gc.gtdb_species_clade_id = sc.gtdb_species_clade_id
    WHERE (sc.GTDB_species LIKE '%Methylobacterium%'
        OR sc.GTDB_species LIKE '%Methylorubrum%')
      AND (e.Preferred_name IN ('xoxF', 'mxaF')
        OR e.KEGG_ko LIKE '%K14028%'
        OR e.KEGG_ko LIKE '%K00114%'
        OR e.EC LIKE '%1.1.2.7%'
        OR e.EC LIKE '%1.1.2.8%')
""")

mdh_all_pd = mdh_all.toPandas()

def classify_mdh(row):
    """Classify MDH using EC/KEGG (reliable) over Preferred_name (unreliable).
    EC 1.1.2.7 / K14028 = true mxaF (calcium-dependent)
    EC 1.1.2.8 / K00114 = xoxF (lanthanide-dependent, often misannotated as mxaF)
    """
    ec = str(row.get('EC', ''))
    kegg = str(row.get('KEGG_ko', ''))
    name = str(row.get('Preferred_name', ''))

    # EC/KEGG classification (takes priority)
    if '1.1.2.7' in ec or 'K14028' in kegg:
        return 'mxaF'
    if '1.1.2.8' in ec or 'K00114' in kegg:
        return 'xoxF'
    # Fallback to name only if no EC/KEGG signal
    if name == 'xoxF':
        return 'xoxF'
    if name == 'mxaF':
        return 'mxaF'
    return 'ambiguous'

mdh_all_pd['mdh_type'] = mdh_all_pd.apply(classify_mdh, axis=1)

# Report ambiguous clusters so we can see what's being dropped
n_ambiguous = (mdh_all_pd['mdh_type'] == 'ambiguous').sum()
print(f"Ambiguous clusters (no EC, no KEGG, unrecognized name): {n_ambiguous}")
if n_ambiguous > 0:
    print(mdh_all_pd[mdh_all_pd['mdh_type'] == 'ambiguous'][
        ['GTDB_species', 'gene_cluster_id', 'Preferred_name', 'EC', 'KEGG_ko']
    ].to_string(index=False))

# Filter out ambiguous for species-level summary
mdh_classified = mdh_all_pd[mdh_all_pd['mdh_type'].isin(['mxaF', 'xoxF'])]

mdh_species_pd = mdh_classified.groupby(['GTDB_species', 'gtdb_species_clade_id']).agg(
    xoxF_clusters=('mdh_type', lambda x: (x == 'xoxF').sum()),
    mxaF_clusters=('mdh_type', lambda x: (x == 'mxaF').sum())
).reset_index()

mdh_species_pd['mdh_profile'] = mdh_species_pd.apply(
    lambda r: 'BOTH' if r['xoxF_clusters'] > 0 and r['mxaF_clusters'] > 0
              else ('xoxF_only' if r['xoxF_clusters'] > 0 else 'mxaF_only'),
    axis=1
)

print(f"\n=== EC/KEGG-based MDH Classification ===")
print("(Corrects for eggNOG misannotation of xoxF as 'mxaF')")
print(f"\nMethylobacterium/Methylorubrum species with MDH annotations: {len(mdh_species_pd)}")
print(mdh_species_pd['mdh_profile'].value_counts())
# Out:
# Ambiguous clusters (no EC, no KEGG, unrecognized name): 0
#
# === EC/KEGG-based MDH Classification ===
# (Corrects for eggNOG misannotation of xoxF as 'mxaF')
#
# Methylobacterium/Methylorubrum species with MDH annotations: 49
# mdh_profile
# BOTH         39
# xoxF_only    10
# Name: count, dtype: int64

# %%
# Step 2: B vitamin gene counts per Methylobacterium/Methylorubrum species
all_gene_names = []
for info in B_VITAMIN_PATHWAYS.values():
    all_gene_names.extend(info['key_genes'])
gene_str = "','".join(all_gene_names)

bvit_by_species = spark.sql(f"""
    SELECT
        sc.GTDB_species,
        sc.gtdb_species_clade_id,
        e.Preferred_name,
        COUNT(*) as n_clusters
    FROM kbase_ke_pangenome.eggnog_mapper_annotations e
    JOIN kbase_ke_pangenome.gene_cluster gc
        ON e.query_name = gc.gene_cluster_id
    JOIN kbase_ke_pangenome.gtdb_species_clade sc
        ON gc.gtdb_species_clade_id = sc.gtdb_species_clade_id
    WHERE (sc.GTDB_species LIKE '%Methylobacterium%'
        OR sc.GTDB_species LIKE '%Methylorubrum%')
      AND e.Preferred_name IN ('{gene_str}')
    GROUP BY sc.GTDB_species, sc.gtdb_species_clade_id, e.Preferred_name
""")

bvit_species_pd = bvit_by_species.toPandas()

# Pivot: species x B vitamin gene presence
bvit_pivot = bvit_species_pd.pivot_table(
    index='GTDB_species', columns='Preferred_name',
    values='n_clusters', fill_value=0
)

# Merge with MDH profile
bvit_pivot = bvit_pivot.merge(
    mdh_species_pd[['GTDB_species', 'mdh_profile']].set_index('GTDB_species'),
    left_index=True, right_index=True, how='inner'
)

print(f"Species with both MDH and B vitamin data: {len(bvit_pivot)}")
print()

for profile in ['BOTH', 'xoxF_only', 'mxaF_only']:
    subset = bvit_pivot[bvit_pivot['mdh_profile'] == profile]
    if len(subset) > 0:
        numeric_cols = [c for c in subset.columns if c != 'mdh_profile']
        gene_counts = subset[numeric_cols].sum(axis=1)
        print(f"{profile} ({len(subset)} species):")
        print(f"  Mean B vitamin genes per species: {gene_counts.mean():.1f} +/- {gene_counts.std():.1f}")
# Out:
# Species with both MDH and B vitamin data: 49
#
# BOTH (39 species):
#   Mean B vitamin genes per species: 54.5 +/- 6.9
# xoxF_only (10 species):
#   Mean B vitamin genes per species: 54.3 +/- 6.5

# %% [markdown]
# ## 9. Visualization

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Left: B vitamin pathway completeness for M. extorquens
pathway_completeness = {}
for pathway, info in B_VITAMIN_PATHWAYS.items():
    expected = set(info['key_genes'])
    found = set(bvit_classified[bvit_classified['pathway'] == pathway]['Preferred_name'].unique()) & expected
    pathway_completeness[pathway.replace('_', '\n')] = len(found) / len(expected) * 100

ax1 = axes[0]
colors = ['#4CAF50' if v >= 80 else '#FF9800' if v >= 50 else '#F44336'
          for v in pathway_completeness.values()]
ax1.bar(pathway_completeness.keys(), pathway_completeness.values(), color=colors)
ax1.set_ylabel('Pathway Completeness (%)')
ax1.set_title('M. extorquens B Vitamin Biosynthesis')
ax1.set_ylim(0, 105)
ax1.axhline(80, color='gray', linestyle='--', alpha=0.5, label='80% threshold')
ax1.legend()
ax1.tick_params(axis='x', rotation=45)

# Right: B vitamin gene count by MDH profile
ax2 = axes[1]
if len(bvit_pivot) > 0:
    numeric_cols = [c for c in bvit_pivot.columns if c != 'mdh_profile']
    profile_labels = ['mxaF only', 'Both', 'xoxF only']
    profile_keys = ['mxaF_only', 'BOTH', 'xoxF_only']
    bar_colors = ['#2196F3', '#9C27B0', '#FF9800']

    for i, (profile, label) in enumerate(zip(profile_keys, profile_labels)):
        subset = bvit_pivot[bvit_pivot['mdh_profile'] == profile]
        if len(subset) > 0:
            gene_counts = subset[numeric_cols].sum(axis=1)
            ax2.bar(i, gene_counts.mean(),
                    yerr=gene_counts.std() if len(subset) > 1 else 0,
                    color=bar_colors[i], capsize=5, label=f'{label} (n={len(subset)})')
    ax2.set_xticks(range(3))
    ax2.set_xticklabels(profile_labels)
    ax2.set_ylabel('B Vitamin Genes per Species')
    ax2.set_title('MDH Profile (EC/KEGG-based) vs B Vitamin Genes\n(Methylobacterium spp.)')
    ax2.legend(fontsize=8)

plt.tight_layout()
plt.savefig('../figures/bvitamin_completeness.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 10. Core vs accessory status of B vitamin genes
#
# Are any B vitamin biosynthesis genes in the accessory genome? If so, different *M. extorquens* strains may have different vitamin requirements.

# %%
print("=== B Vitamin Gene Core/Accessory Status ===")
print()
for pathway, info in B_VITAMIN_PATHWAYS.items():
    pw_genes = bvit_classified[bvit_classified['pathway'] == pathway]
    if len(pw_genes) == 0:
        print(f"{pathway}: No genes found")
        continue

    core_genes = sorted(pw_genes[pw_genes['is_core'] == True]['Preferred_name'].unique())
    aux_genes = sorted(pw_genes[pw_genes['is_auxiliary'] == True]['Preferred_name'].unique())
    sing_genes = sorted(pw_genes[pw_genes['is_singleton'] == True]['Preferred_name'].unique())

    print(f"{pathway}:")
    if core_genes:
        print(f"  Core (all strains): {core_genes}")
    if aux_genes:
        print(f"  Auxiliary (some strains): {aux_genes}")
    if sing_genes:
        print(f"  Singleton (one strain): {sing_genes}")
    print()

print("Accessory/singleton B vitamin genes indicate strain-specific")
print("auxotrophies - different strains may need different supplements.")
# Out:
# === B Vitamin Gene Core/Accessory Status ===
#
# B1_thiamine:
#   Core (all strains): ['-', 'amiD', 'thiC', 'thiD', 'thiE', 'thiG', 'thiL', 'thiS']
#   Auxiliary (some strains): ['thiG', 'thiL']
#   Singleton (one strain): ['thiG', 'thiL']
#
# B2_riboflavin:
#   Core (all strains): ['ribB', 'ribD', 'ribE', 'ribH']
#
# B6_pyridoxine:
#   Core (all strains): ['-', 'pdxA', 'pdxH', 'pdxJ', 'pdxY']
#   Auxiliary (some strains): ['pdxB']
#
# B7_biotin:
#   Core (all strains): ['MA20_09775', 'bioA', 'bioB', 'bioC', 'bioD', 'bioF']
#   Auxiliary (some strains): ['-', 'MA20_09775', 'bioA', 'bioD', 'bioH']
#   Singleton (one strain): ['bioA', 'bioD']
#
# B9_folate:
#   Core (all strains): ['-', 'folA', 'folB', 'folC', 'folE', 'folK', 'folP', 'pabA', 'pabB']
#   Auxiliary (some strains): ['folC']
#   Singleton (one strain): ['folC']
#
# B12_cobalamin:
#   Core (all strains): ['MA20_20540', 'bluB', 'cobA', 'cobB', 'cobC', 'cobD', 'cobG', 'cobH', 'cobI', 'cobJ', 'cobK', 'cobL', 'cobM', 'cobN', 'cobO', 'cobP', 'cobQ', 'cobS', 'cobT', 'cobW', 'nirA']
#   Auxiliary (some strains): ['cobA', 'cobC', 'cobD', 'cobH', 'cobI', 'cobJ', 'cobK', 'cobL', 'cobM', 'cobN', 'cobO', 'cobP', 'cobQ', 'cobS', 'cobT']
#   Singleton (one strain): ['cobA', 'cobC', 'cobD', 'cobH', 'cobI', 'cobJ', 'cobK', 'cobL', 'cobM', 'cobN', 'cobO', 'cobP', 'cobQ', 'cobS', 'cobT']
#
# Accessory/singleton B vitamin genes indicate strain-specific
# auxotrophies - different strains may need different supplements.

# %% [markdown]
# ## 11. Summary
#
# ### B Vitamin Biosynthesis in M. extorquens
# - **360 gene clusters** matched B vitamin biosynthesis queries across both *M. extorquens* pangenomes (22 + 4 genomes)
# - **Biotin (B7)** and **folate (B9)**: 100% complete -- all expected biosynthesis genes found as core (B9 now includes pabA/pabB as direct precursors; moa\*/que\* contamination from molybdopterin/queuosine pathways removed)
# - **Cobalamin (B12)**: 83% complete (19/23 expected genes found) -- above the 80% auxotrophy threshold (previously 78% when bch\* bacteriochlorophyll genes inflated the pathway)
# - **Pyridoxine (B6)**: 80% complete (missing pdxK, a kinase for salvage rather than de novo synthesis)
# - **Thiamine (B1)**: 75% complete (missing thiM, thiO)
# - **Riboflavin (B2)**: 67% complete (missing ribA, ribC) -- the cleanest auxotrophy signal, since all found rib genes are core and the missing genes are absent from all strains
#
# ### Predicted Auxotrophies and Medium Implications
# Two pathways fall below 80% completeness, suggesting potential auxotrophies:
# 1. **Riboflavin (B2)**: supplement with riboflavin (67% complete, missing ribA and ribC across all strains)
# 2. **Thiamine (B1)**: supplement with thiamine HCl (75% complete, missing thiM and thiO)
#
# B12 cobalamin is no longer predicted as an auxotrophy (83% completeness after removing bch\* contamination), though strain-level variation in cob gene content means some strains may still benefit from supplementation.
#
# ### B12 Cobalamin: Most Variable Across Strains
# B12 biosynthesis shows the most striking core/accessory variation. Many cob genes (cobA, cobC, cobD, cobH, cobI, cobJ, cobK, cobL, cobM, cobN, cobO, cobP, cobQ, cobS, cobT) appear simultaneously as **core, auxiliary, AND singleton** -- meaning some strains have them in their core genome while others carry them as accessory or unique genes. This is the strongest signal for strain-specific B12 requirements and suggests *M. extorquens* strains differ in their cobalamin self-sufficiency.
#
# ### Pathway Definition Audit
# The B vitamin pathway classifier was tightened to match only by gene name (`key_genes`) and KEGG ortholog (`key_kos`), removing a KEGG pathway number fallback that pulled in genes from related but distinct pathways:
# - **B12**: removed bch\* (bacteriochlorophyll), bfr (bacterioferritin), and other porphyrin metabolism genes that share the tetrapyrrole trunk pathway but are not cobalamin biosynthesis
# - **B9**: removed moa\*/mob\*/moe\* (molybdopterin), que\* (queuosine), dmrA, and trpE/trpG that share GTP as a precursor but are separate pathways
# - Added pabA/pabB (para-aminobenzoate synthase) to B9 as direct folate precursors
#
# ### xoxF/mxaF and Lanthanide Biology (EC/KEGG-based classification)
# - **Classification method**: MDH type is assigned by EC number and KEGG ortholog rather than eggNOG `Preferred_name`. Cell 7 demonstrated that eggNOG systematically labels xoxF clusters as "mxaF" when they carry EC 1.1.2.8 / K00114. EC 1.1.2.7 / K14028 = true mxaF (calcium-dependent); EC 1.1.2.8 / K00114 = xoxF (lanthanide-dependent).
# - **Taxonomy scope**: Filter includes both *Methylobacterium* and *Methylorubrum* (Green & Ardley 2018 reclassification).
# - **49 *Methylobacterium* species** with MDH annotations: **0 mxaF-only**, **39 BOTH (xoxF + mxaF)**, **10 xoxF-only** (zero ambiguous clusters)
# - **The EC/KEGG reclassification completely inverted the MDH profile** compared to the gene-name-based result (which was 44 mxaF-only / 5 BOTH / 0 xoxF-only). The prior result was an annotation artifact: eggNOG's `Preferred_name` field systematically misannotates xoxF as mxaF in *Methylobacterium*.
# - **Lanthanide-dependent methanol oxidation (xoxF) is ubiquitous in *Methylobacterium***: every species with MDH carries xoxF. The xoxF-only species (n=10) lack mxaF entirely, while 39 species carry both enzymes. No species has mxaF without xoxF.
# - **B vitamin gene counts**: BOTH species average **54.5** B vitamin genes vs **54.3** for xoxF-only -- no meaningful difference. MDH profile does not predict B vitamin biosynthetic capacity in this genus.
#
# ### Testable Predictions
# 1. *M. extorquens* AM1 growth should be enhanced by supplementing riboflavin and/or thiamine
# 2. Different strains may have different B12 requirements given the high core/accessory variability of cob genes, despite the pathway being >80% complete at the species level
# 3. xoxF-only *Methylobacterium* species (n=10) should grow poorly or not at all without lanthanide supplementation, while BOTH species (n=39) should switch between XoxF and MxaF depending on lanthanide availability
#
# ### Next Steps
# - Validate auxotrophy predictions with growth experiments (vitamin dropout media)
# - Sequence-level phylogenetic analysis of PQQ MDH genes to further validate xoxF vs mxaF identity beyond EC/KEGG
# - Extend to other methylotrophic genera (Methylocystis, Methylomonas, Methylophaga)
# - Cross-reference with environmental metadata analysis in notebooks 02-03
