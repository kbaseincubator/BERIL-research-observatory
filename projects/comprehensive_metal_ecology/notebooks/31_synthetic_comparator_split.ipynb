# %% [markdown]
# # NB31 — Synthetic Comparator Split Analysis
#
# **Type:** Exploratory post-hoc
#
# **Purpose:** Construct a synthetic vertical/mobile gene set comparator
# to benchmark the cofactor/resistance PGLS split. Requires Spark (JupyterHub).
#
# **Script:** `scripts/synthetic_comparator_split.py`
#
# **Outputs:**
# - `data/synthetic_comparator_presence.parquet` (Spark presence matrix, cached)
# - `data/synthetic_comparator_split_results.csv` (PGLS + permutation results)

# %%
import os, sys
os.environ['OMP_NUM_THREADS'] = '1'
from pathlib import Path

# Change to project root so relative paths work
PROJECT = Path('/home/hmacgregor/BERIL-research-observatory/projects/comprehensive_metal_ecology')
# %cd {PROJECT}
sys.path.insert(0, str(PROJECT))

# %%
# Run the synthetic comparator analysis
# On first run: executes Spark query, caches presence matrix
# On re-runs:   loads cache, runs PGLS + permutation only
# %run scripts/synthetic_comparator_split.py
